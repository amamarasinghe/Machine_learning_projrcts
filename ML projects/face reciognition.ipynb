# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
from sklearn.datasets import fetch_olivetti_faces

# %%
faces=fetch_olivetti_faces(shuffle=True,random_state=42)
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\amama\scikit_learn_data

# %%
X=faces.data

# %%
n_sample,n_features=X.shape

# %%
n_sample
# Out:
# 400

# %%
n_features
# Out:
# 4096

# %%
image_shape = faces.images[0].shape
image_shape
# Out:
# (64, 64)

# %%
n_components = 150

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=n_components,whiten=True,random_state=42)
X_pca = pca.fit_transform(X)

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(3,4,i+1)
    plt.imshow(faces.images[i],cmap='gray')
    plt.title(f'Face{i+1}')
    plt.axis('off')

plt.suptitle('same faces from the dataset')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n_print =12
print("prportion of total variation explained by the first 12pcs")
for i in range (n_print):
    variant_explained=pca.explained_variance__[i]
    print(f"{i+1}:{variant_explained*100:.if}%")
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
cumulative_variances=np.cumsum(pca.explained_variance_ratio_)

# %%
plt.figure(figsize=(8.5))
plt.plot(np.arange(1))

# %%
n_eligenfaces = 12
plt.figure(figsize=(12,6))
for i
